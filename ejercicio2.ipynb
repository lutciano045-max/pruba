# %% [markdown]
# ## Ejercicio
#
# Escribir un programa que pregunte el nombre completo del usuario en la consola y después muestre por pantalla el nombre completo del usuario tres veces, una con todas las letras minúsculas, otra con todas las letras mayúsculas y otra solo con la primera letra del nombre y de los apellidos en mayúscula. El usuario puede introducir su nombre combinando mayúsculas y minúsculas como quiera.

# %% [markdown]
# ## Solución

# %%
nombre_completo = str(input("Ingrese nombre completo: "))
nombre_completo.lower() #minuscula
nombre_completo.upper() #MAYÚSCULAS
for nombre_completo in range():
    print(nombre_completo)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 nombre_completo = str(input("Ingrese nombre completo: "))
#       2 nombre_completo.lower() #minuscula
#       3 nombre_completo.upper() #MAYÚSCULAS
# ----> 4 for nombre_completo in range(nombre_completo):
#       5     print(nombre_completo)
#       6
#
# TypeError: 'str' object cannot be interpreted as an integer
